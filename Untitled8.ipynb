# %% [markdown]
# <a href="https://colab.research.google.com/github/MURALI-13062005/CRT/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

(ds_train, ds_test), ds_info = tfds.load(
    'emnist/balanced',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

def normalize_img(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.reshape(image, [-1])
    return image, label

batch_size = 128
ds_train = ds_train.map(normalize_img).cache().shuffle(1000).batch(batch_size).prefetch(tf.data.AUTOTUNE)
ds_test = ds_test.map(normalize_img).batch(batch_size).cache().prefetch(tf.data.AUTOTUNE)

num_classes = ds_info.features['label'].num_classes

model = models.Sequential([
    layers.Input(shape=(28*28,)),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)





model.summary()
history = model.fit(ds_train, epochs=10, validation_data=ds_test)

test_loss, test_acc = model.evaluate(ds_test)
print(f"Test Accuracy: {test_acc*100:.2f}%")

import numpy as np

for images, labels in ds_test.take(1):
    preds = model.predict(images)
    preds_cls = np.argmax(preds, axis=1)

    plt.figure(figsize=(12, 6))
    for i in range(10):
        plt.subplot(2, 5, i+1)
        plt.imshow(tf.reshape(images[i], (28, 28)), cmap='gray')
        plt.title(f"True: {labels[i].numpy()} | Pred: {preds_cls[i]}")
        plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/emnist/balanced/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/emnist/balanced/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/balanced/incomplete.7CK7N9_3.1.0/emnist-train.tfrecord*...:   0%|  …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/balanced/incomplete.7CK7N9_3.1.0/emnist-test.tfrecord*...:   0%|   …
# Dataset emnist downloaded and prepared to /root/tensorflow_datasets/emnist/balanced/3.1.0. Subsequent calls will reuse this data.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 47)             │        12,079 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545,327 (2.08 MB)
#  Trainable params: 545,327 (2.08 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 34s 37ms/step - accuracy: 0.5285 - loss: 1.6855 - val_accuracy: 0.7969 - val_loss: 0.6540
# Epoch 2/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.7607 - loss: 0.7463 - val_accuracy: 0.8227 - val_loss: 0.5480
# Epoch 3/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.7947 - loss: 0.6272 - val_accuracy: 0.8344 - val_loss: 0.5025
# Epoch 4/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.8115 - loss: 0.5681 - val_accuracy: 0.8385 - val_loss: 0.4812
# Epoch 5/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.8218 - loss: 0.5279 - val_accuracy: 0.8461 - val_loss: 0.4609
# Epoch 6/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - accuracy: 0.8264 - loss: 0.5074 - val_accuracy: 0.8466 - val_loss: 0.4598
# Epoch 7/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.8324 - loss: 0.4839 - val_accuracy: 0.8476 - val_loss: 0.4492
# Epoch 8/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.8370 - loss: 0.4676 - val_accuracy: 0.8495 - val_loss: 0.4512
# Epoch 9/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.8431 - loss: 0.4481 - val_accuracy: 0.8522 - val_loss: 0.4412
# Epoch 10/10
# 882/882 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8453 - loss: 0.4378 - val_accuracy: 0.8529 - val_loss: 0.4441
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8535 - loss: 0.4342
# Test Accuracy: 85.29%
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
